# %%
import numpy as np
import pandas as pd

# %%
pd.options.display.max_columns = 81
pd.options.display.max_rows = 20

# %%
train_df = pd.read_csv("train.csv")

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
train_df.shape
# Out:
# (1460, 81)

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
train_df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
train_df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
train_df.isna().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
#                  ...
# PoolArea            0
# PoolQC           1453
# Fence            1179
# MiscFeature      1406
# MiscVal             0
# MoSold              0
# YrSold              0
# SaleType            0
# SaleCondition       0
# SalePrice           0
# Length: 81, dtype: int64

# %%
cols = train_df.columns
for col in cols:
    if (train_df[col].isna().sum()) > 0:
        print('{} has {} values missing'.format(col,train_df[col].isna().sum()))
        print('\n')
# Out:
# LotFrontage has 259 values missing
#
#
# Alley has 1369 values missing
#
#
# MasVnrType has 8 values missing
#
#
# MasVnrArea has 8 values missing
#
#
# BsmtQual has 37 values missing
#
#
# BsmtCond has 37 values missing
#
#
# BsmtExposure has 38 values missing
#
#
# BsmtFinType1 has 37 values missing
#
#
# BsmtFinType2 has 38 values missing
#
#
# Electrical has 1 values missing
#
#
# FireplaceQu has 690 values missing
#
#
# GarageType has 81 values missing
#
#
# GarageYrBlt has 81 values missing
#
#
# GarageFinish has 81 values missing
#
#
# GarageQual has 81 values missing
#
#
# GarageCond has 81 values missing
#
#
# PoolQC has 1453 values missing
#
#
# Fence has 1179 values missing
#
#
# MiscFeature has 1406 values missing

# %%
string_cols = train_df.select_dtypes(include="object")
numeric_cols = train_df.select_dtypes(include=np.number)

# %%
string_cols_list = string_cols.columns
string_cols_list
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
numeric_cols_list = numeric_cols.columns
numeric_cols_list
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
numeric_cols.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %%
string_cols.head()
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl  \
# 0      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 1      Veenker      Feedr       Norm     1Fam     1Story     Gable  CompShg
# 2      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 3      Crawfor       Norm       Norm     1Fam     2Story     Gable  CompShg
# 4      NoRidge       Norm       Norm     1Fam     2Story     Gable  CompShg
#
# ...

# %%
numeric_cols_corr = numeric_cols.corr()
numeric_cols_corr
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# ...                 ...         ...          ...       ...          ...
# WoodDeckSF    -0.029643   -0.012579     0.088521  0.171698     0.238923
# ...

# %%
for col in string_cols_list:
    print(col)
    print(string_cols[col].value_counts())
    print('-------------------------------------------------------------------')
# Out:
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64
# -------------------------------------------------------------------
# Street
# Pave    1454
# Grvl       6
# Name: Street, dtype: int64
# -------------------------------------------------------------------
# Alley
# Grvl    50
# Pave    41
# Name: Alley, dtype: int64
# -------------------------------------------------------------------
# LotShape
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: LotShape, dtype: int64
# -------------------------------------------------------------------
# LandContour
# Lvl    1311
# Bnk      63
# HLS      50
# Low      36
# Name: LandContour, dtype: int64
# -------------------------------------------------------------------
# Utilities
# AllPub    1459
# NoSeWa       1
# Name: Utilities, dtype: int64
# -------------------------------------------------------------------
# LotConfig
# Inside     1052
# ...

# %%
for col in numeric_cols_list:
    print(col)
    print(numeric_cols[col].value_counts())
    print('---------------------------------------------------------')
# Out:
# Id
# 1460    1
# 479     1
# 481     1
# 482     1
# 483     1
# 484     1
# 485     1
# 486     1
# 487     1
# 488     1
#        ..
# 980     1
# 972     1
# 973     1
# 974     1
# 975     1
# 976     1
# 977     1
# 978     1
# 979     1
# 1       1
# Name: Id, Length: 1460, dtype: int64
# ---------------------------------------------------------
# MSSubClass
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: MSSubClass, dtype: int64
# ---------------------------------------------------------
# LotFrontage
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
# 65.0      44
# 85.0      40
# 78.0      25
# 21.0      23
# 90.0      23
#         ...
# 160.0      1
# 168.0      1
# 128.0      1
# 144.0      1
# 39.0       1
# 106.0      1
# 38.0       1
# 138.0      1
# 140.0      1
# 137.0      1
# ...

# %%
for col in numeric_cols:
    if (numeric_cols[col].isna().sum()) > 0:
        print('{} mean value {} '.format(col,train_df[col].mean()))
        print('\n')
# Out:
# LotFrontage mean value 70.04995836802665
#
#
# MasVnrArea mean value 103.68526170798899
#
#
# GarageYrBlt mean value 1978.5061638868744

# %%
for col in string_cols:
    if (string_cols[col].isna().sum()) > 0:
        print('{} has {} values missing'.format(col,string_cols[col].isna().sum()))
# Out:
# Alley has 1369 values missing
# MasVnrType has 8 values missing
# BsmtQual has 37 values missing
# BsmtCond has 37 values missing
# BsmtExposure has 38 values missing
# BsmtFinType1 has 37 values missing
# BsmtFinType2 has 38 values missing
# Electrical has 1 values missing
# FireplaceQu has 690 values missing
# GarageType has 81 values missing
# GarageFinish has 81 values missing
# GarageQual has 81 values missing
# GarageCond has 81 values missing
# PoolQC has 1453 values missing
# Fence has 1179 values missing
# MiscFeature has 1406 values missing

# %%
train_df_corr = train_df.corr()
train_df_corr
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# ...                 ...         ...          ...       ...          ...
# WoodDeckSF    -0.029643   -0.012579     0.088521  0.171698     0.238923
# ...

# %% [markdown]
# # Data visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style(style='whitegrid')

# %%
for col in string_cols_list:
    sns.countplot(x=col, data =train_df)
    plt.title(col)
    plt.show()

# %%
#sns.pairplot(data=numeric_cols)

# %%
for col in numeric_cols_list:
    sns.regplot(x=col, y='SalePrice',data =train_df)
    plt.title(col)
    plt.show()

# %%
# for col in numeric_cols_list:
#     sns.distplot(train_df[col],kde=False, bins=30)
#     plt.title(col)
#     plt.show()

# %%
plt.figure(figsize= (10,10))
sns.heatmap(train_df_corr, cmap='magma', linewidth=2, linecolor='white')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.heatmap(numeric_cols.isnull(), yticklabels=False, cbar=False, cmap='magma')

# %%
plt.figure(figsize=(5,5))
sns.heatmap(string_cols.isnull(), yticklabels=False, cbar=False, cmap='magma')

# %%
# for col in numeric_cols:
#     if col != "SalePrice":
#         plt.bar(x=numeric_cols[col], height=numeric_cols['SalePrice'])
# plt.show()

# %%
drop_string_cols = ['Alley','PoolQC','Fence','MiscFeature']

# %%
train_df.drop(drop_string_cols, axis=1,inplace=True)

# %%
train_df.shape
# Out:
# (1460, 77)

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
# ...

# %%
values = {'LotFrontage': train_df['LotFrontage'].mean(), 'MasVnrArea': train_df['MasVnrArea'].mean(),
          'GarageYrBlt': train_df['GarageYrBlt'].mean()}
#fill_num_na_col = ['LotFrontage', 'MasVnrArea','GarageYrBlt']
train_df.fillna(value=values, axis =0,inplace=True )

# %%
num_na_cols = ['LotFrontage', 'MasVnrArea','GarageYrBlt']
train_df[num_na_cols].isna().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
string_cols.isna().sum()
# Out:
# MSZoning            0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
#                  ...
# GarageType         81
# GarageFinish       81
# GarageQual         81
# GarageCond         81
# PavedDrive          0
# PoolQC           1453
# Fence            1179
# MiscFeature      1406
# SaleType            0
# SaleCondition       0
# Length: 43, dtype: int64

# %%
train_df.fillna(method='ffill', axis = 0, inplace = True)

# %%
cols = train_df.columns
for col in cols:
    if (train_df[col].isna().sum()) > 0:
        print('{} has {} values missing'.format(col,train_df[col].isna().sum()))
        print('\n')
# Out:
# FireplaceQu has 1 values missing

# %%
string_cols['FireplaceQu'].head()
# Out:
# 0    NaN
# 1     TA
# 2     TA
# 3     Gd
# 4     TA
# Name: FireplaceQu, dtype: object

# %%
train_df.fillna(method='bfill',axis=0,inplace=True)

# %%
cols = train_df.columns
for col in cols:
    if (train_df[col].isna().sum()) > 0:
        print('{} has {} values missing'.format(col,train_df[col].isna().sum()))
        print('\n') 
    else:
        print('no missing value')
# Out:
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# no missing value
# ...

# %%
from  sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
new_string_cols = train_df.select_dtypes(include='object')
new_string_cols_list = new_string_cols.columns
new_string_cols_list
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
new_num_cols = train_df.select_dtypes(include=np.number)
new_num_cols_list = new_num_cols.columns
new_num_cols_list
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
new_string_cols.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 39 columns):
# MSZoning         1460 non-null object
# Street           1460 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# RoofStyle        1460 non-null object
# RoofMatl         1460 non-null object
# Exterior1st      1460 non-null object
# Exterior2nd      1460 non-null object
# MasVnrType       1460 non-null object
# ExterQual        1460 non-null object
# ExterCond        1460 non-null object
# Foundation       1460 non-null object
# BsmtQual         1460 non-null object
# BsmtCond         1460 non-null object
# ...

# %%
new_train_df = pd.DataFrame(new_num_cols)
for col in new_string_cols:
    new_train_df[col] = le.fit_transform(new_string_cols[col])

# %%
new_train_df.shape
# Out:
# (1460, 77)

# %%
train_df.shape
# Out:
# (1460, 77)

# %%
new_train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %%
X = new_train_df.drop(['Id','SalePrice'], axis=1)
y = new_train_df['SalePrice']

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
best_features = SelectKBest(score_func=chi2,k='all')

# %%
fit = best_features.fit(X,y)

# %%
feat_sel_dict = {'column':X.columns,'sel_score':fit.scores_}
feat_sel_df = pd.DataFrame(feat_sel_dict)
#feat_sel_df.head()
feat_sel_df.nlargest(78,'sel_score')
# Out:
#           column     sel_score
# 2        LotArea  1.011497e+07
# 33       MiscVal  6.253332e+06
# 13      2ndFlrSF  4.648841e+05
# 8     BsmtFinSF1  3.999851e+05
# 32      PoolArea  3.835642e+05
# 9     BsmtFinSF2  3.688827e+05
# 7     MasVnrArea  2.857403e+05
# 10     BsmtUnfSF  2.747512e+05
# 14  LowQualFinSF  2.448810e+05
# 15     GrLivArea  1.968501e+05
# ..           ...           ...
# 72    PavedDrive  9.328926e+01
# 54     ExterCond  8.776960e+01
# 70    GarageQual  6.788074e+01
# 61       Heating  6.761324e+01
# 63    CentralAir  5.380233e+01
# 71    GarageCond  4.078517e+01
# 21  KitchenAbvGr  2.849083e+01
# 45    Condition2  2.733648e+01
# 37        Street  3.650601e+00
# 35        YrSold  6.029712e-01
#
# [75 rows x 2 columns]

# %%
X.shape
# Out:
# (1460, 75)

# %%
from sklearn.preprocessing import StandardScaler

# %%
stand_scale = StandardScaler()

# %%
X = stand_scale.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.15, random_state= 101)

# %%
from sklearn.svm import SVR

# %%
svr_cls = SVR()

# %%
svr_cls.fit(X_train,y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
svr_cls.score(X_train,y_train)
# Out:
# -0.05177194964941112

# %%
svr_cls_pred = svr_cls.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, accuracy_score

# %%
mean_squared_error(y_test,svr_cls_pred)
# Out:
# 6225964886.903379

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr = GradientBoostingRegressor()

# %%
gbr.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=3, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=100, presort='auto', random_state=None,
#              subsample=1.0, verbose=0, warm_start=False)

# %%
gbr_pred = gbr.predict(X_test)

# %%
mean_squared_error(y_test,gbr_pred)
# Out:
# 615171578.4770422
